# %%
import ipaddress
from ip2geotools.databases.noncommercial import DbIpCity
import geoip2.database

def ip_str_to_int(ip: str) -> int:
    """ Converts IP address from string to int
    Args:
        ip (str): IP address as a string  
    Returns:
        ip (int): IP address as an int
    """
    return int(ipaddress.ip_address(ip))


def ip_int_to_str(ip: int)  -> str:
    """ Converts IP address from string to int
    Args:
        ip (str): IP address as a string  
    Returns:
        ip (int): IP address as an int
    """
    return str(ipaddress.ip_network(ip)).partition("/")[0]


def ip_str_to_city(ip: str) -> str:
    """ Looks up city name for a given stringified IP address
    Args:
        ip (str): IP address as a string  
    Returns:
        city-name (str): City where the IP address is located
    """
    response = DbIpCity.get(ip, api_key='free')
    return response.city



# Create an account and download this file (for free) from here:
# https://dev.maxmind.com/geoip/docs/databases/city-and-country?lang=en
def ip_str_to_city2(ip: str) -> str:
    """ Looks up city name for a given stringified IP address
    Args:
        ip (str): IP address as a string  
    Returns:
        city-name (str): City where the IP address is located
    """
    # Create an account and download this file (for free) from here:
    # https://dev.maxmind.com/geoip/docs/databases/city-and-country?lang=en
    with geoip2.database.Reader('./GeoLite2-City.mmdb') as reader:
        try:
            response = reader.city(ip)
            return response.city.name
        except geoip2.errors.AddressNotFoundError:
            return "Dublin"

# %%
from datetime import datetime
 
def date_string_to_timestamp(input_date : str) -> int:
    """ Converts stringified date to a timestamp
    Args:
        input_date (str): The input  
    Returns:
        timestamp (int): The Unix timestamp
    """
    date_format = "%m-%d-%Y %H:%M %S"
    return int(float(datetime.strptime(input_date, date_format).timestamp()) * 1000)

# %%
import hsfs
import pandas as pd

def connect(featurestore : str) -> hsfs.Connection.connection:
    print("Connecting....")
    return hsfs.connection(
        host="791bb4a0-bb1c-11ec-8721-7bd8cdac0b54.cloud.hopsworks.ai", # hostname for your Hopsworks cluster
        project=featurestore,
        engine="hive",
        secrets_store="local",
        api_key_file="./api-key.txt"
    )


def engineer_features(df: pd.DataFrame) -> pd.DataFrame:
    print("Creating features....")
    df['ip_str'] = df.ip.apply(ip_int_to_str)
    df['city'] = df.ip_str.apply(ip_str_to_city2)
    return df


def read_data(path: str) -> pd.DataFrame: 
    print("Reading raw data....")
    return pd.read_csv(path, dtype={'is_attributed': 'bool'}, parse_dates=['click_time'])


def run(project: str) : 
    # First, you have to create a project on Hopsworks called 'prod'
    connection = connect(project)
    fs = connection.get_feature_store()
    df = read_data("sample-click-logs.csv")
    df = engineer_features(df)

    print("Writing features to feature store....")
    fg_name="clicks"
    version=1
    try:
        fg = fs.get_feature_group(fg_name,version=version)
        fg.insert(df)
    except:
        print("Creating feature group...")
        fg = fs.create_feature_group(fg_name,
                        version=version,
                        description="User clicks on our website",
                        primary_key=['id'],
                        online_enabled=True)
        fg.save(df)
    connection.close()

run("prod")

# %%
# !cd .. && pytest notebook-tests
# Out:
# F                                                                        [100%]
# =================================== FAILURES ===================================
# ___________ test_notebook_exec[notebooks/feature_engineering.ipynb] ____________
#
# notebook = 'notebooks/feature_engineering.ipynb'
#
# >   ???
#
# /home/jdowling/Projects/ml-testing/ex2/notebook-tests/test_features_notebook.py:11:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <nbconvert.preprocessors.execute.ExecutePreprocessor object at 0x7f94a8bcf8b0>
# nb = {'cells': [{'cell_type': 'code', 'execution_count': 1, 'id': 'exclusive-majority', 'metadata': {}, 'outputs': [], 'sou...'nbconvert_exporter': 'python', 'pygments_lexer': 'ipython3', 'version': '3.9.5'}}, 'nbformat': 4, 'nbformat_minor': 5}
# resources = {}, km = None
#
#     def preprocess(self, nb, resources=None, km=None):
#         """
#         Preprocess notebook executing each code cell.
#
#         The input argument `nb` is modified in-place.
#
#         Parameters
#         ----------
#         nb : NotebookNode
#             Notebook being executed.
#         resources : dictionary (optional)
#             Additional resources used in the conversion process. For example,
#             passing ``{'metadata': {'path': run_path}}`` sets the
#             execution path to ``run_path``.
#         km: KernelManager (optional)
#             Optional kernel manager. If none is provided, a kernel manager will
#             be created.
#
#         Returns
#         -------
#         nb : NotebookNode
#             The executed notebook.
#         resources : dictionary
#             Additional resources used in the conversion process.
#         """
#
#         if not resources:
#             resources = {}
#
#         with self.setup_preprocessor(nb, resources, km=km):
#             self.log.info("Executing notebook with kernel: %s" % self.kernel_name)
# >           nb, resources = super(ExecutePreprocessor, self).preprocess(nb, resources)
#
# /usr/lib/python3/dist-packages/nbconvert/preprocessors/execute.py:405:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <nbconvert.preprocessors.execute.ExecutePreprocessor object at 0x7f94a8bcf8b0>
# nb = {'cells': [{'cell_type': 'code', 'execution_count': 1, 'id': 'exclusive-majority', 'metadata': {}, 'outputs': [], 'sou...'nbconvert_exporter': 'python', 'pygments_lexer': 'ipython3', 'version': '3.9.5'}}, 'nbformat': 4, 'nbformat_minor': 5}
# resources = {}
#
#     def preprocess(self, nb, resources):
#         """
#         Preprocessing to apply on each notebook.
#
#         Must return modified nb, resources.
#
#         If you wish to apply your preprocessing to each cell, you might want
#         to override preprocess_cell method instead.
#
#         Parameters
#         ----------
#         nb : NotebookNode
#             Notebook being converted
#         resources : dictionary
#             Additional resources used in the conversion process.  Allows
#             preprocessors to pass variables into the Jinja engine.
#         """
#         for index, cell in enumerate(nb.cells):
# >           nb.cells[index], resources = self.preprocess_cell(cell, resources, index)
#
# /usr/lib/python3/dist-packages/nbconvert/preprocessors/base.py:69:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <nbconvert.preprocessors.execute.ExecutePreprocessor object at 0x7f94a8bcf8b0>
# cell = {'cell_type': 'code', 'execution_count': 3, 'id': 'decreased-departure', 'metadata': {}, 'outputs': [{'output_type': '...[\'id\'],\n                        online_enabled=True)\n        fg.save(df)\n    connection.close()\n\nrun("prod")\n'}
# resources = {}, cell_index = 2, store_history = True
#
#     def preprocess_cell(self, cell, resources, cell_index, store_history=True):
#         """
#         Executes a single code cell. See base.py for details.
#
#         To execute all cells see :meth:`preprocess`.
#         """
#         if cell.cell_type != 'code' or not cell.source.strip():
#             return cell, resources
#
#         reply, outputs = self.run_cell(cell, cell_index, store_history)
#         # Backwards compatibility for processes that wrap run_cell
#         cell.outputs = outputs
#
#         cell_allows_errors = (self.allow_errors or "raises-exception"
#                               in cell.metadata.get("tags", []))
#
#         if self.force_raise_errors or not cell_allows_errors:
#             for out in cell.outputs:
#                 if out.output_type == 'error':
# >                   raise CellExecutionError.from_cell_and_msg(cell, out)
# E                   nbconvert.preprocessors.execute.CellExecutionError: An error occurred while executing the following cell:
# E                   ------------------
# E                   import hsfs
# E                   import pandas as pd
# E
# E                   def connect(featurestore : str) -> hsfs.Connection.connection:
# E                       print("Connecting....")
# E                       return hsfs.connection(
# E                           host="791bb4a0-bb1c-11ec-8721-7bd8cdac0b54.cloud.hopsworks.ai", # hostname for your Hopsworks cluster
# E                           project=featurestore,
# E                           engine="hive",
# E                           secrets_store="local",
# E                           api_key_file="./api-key.txt"
# E                       )
# E
# E
# E                   def engineer_features(df: pd.DataFrame) -> pd.DataFrame:
# E                       print("Creating features....")
# E                       df['ip_str'] = df.ip.apply(ip_int_to_str)
# E                       df['city'] = df.ip_str.apply(ip_str_to_city2)
# E                       return df
# E
# E
# E                   def read_data(path: str) -> pd.DataFrame:
# E                       print("Reading raw data....")
# E                       return pd.read_csv(path, dtype={'is_attributed': 'bool'}, parse_dates=['click_time'])
# E
# E
# E                   def run(project: str) :
# E                       # First, you have to create a project on Hopsworks called 'prod'
# E                       connection = connect(project)
# E                       fs = connection.get_feature_store()
# E                       df = read_data("sample-click-logs.csv")
# E                       df = engineer_features(df)
# E
# E                       print("Writing features to feature store....")
# E                       fg_name="clicks"
# E                       version=1
# E                       try:
# E                           fg = fs.get_feature_group(fg_name,version=version)
# E                           fg.insert(df)
# E                       except:
# E                           print("Creating feature group...")
# E                           fg = fs.create_feature_group(fg_name,
# E                                           version=version,
# E                                           description="User clicks on our website",
# E                                           primary_key=['id'],
# E                                           online_enabled=True)
# E                           fg.save(df)
# E                       connection.close()
# E
# E                   run("prod")
# E
# E                   ------------------
# E
# E                   ---------------------------------------------------------------------------
# E                   RestAPIError                              Traceback (most recent call last)
# E                   <ipython-input-3-e5bd4e38b044> in <module>
# E                        48     connection.close()
# E                        49
# E                   ---> 50 run("prod")
# E
# E                   <ipython-input-3-e5bd4e38b044> in run(project)
# E                        27 def run(project: str) :
# E                        28     # First, you have to create a project on Hopsworks called 'prod'
# E                   ---> 29     connection = connect(project)
# E                        30     fs = connection.get_feature_store()
# E                        31     df = read_data("sample-click-logs.csv")
# E
# E                   <ipython-input-3-e5bd4e38b044> in connect(featurestore)
# E                         4 def connect(featurestore : str) -> hsfs.Connection.connection:
# E                         5     print("Connecting....")
# E                   ----> 6     return hsfs.connection(
# E                         7         host="791bb4a0-bb1c-11ec-8721-7bd8cdac0b54.cloud.hopsworks.ai", # hostname for your Hopsworks cluster
# E                         8         project=featurestore,
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/connection.py in connection(cls, host, port, project, engine, region_name, secrets_store, hostname_verification, trust_store_path, cert_folder, api_key_file, api_key_value)
# E                       305     ):
# E                       306         """Connection factory method, accessible through `hsfs.connection()`."""
# E                   --> 307         return cls(
# E                       308             host,
# E                       309             port,
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/connection.py in __init__(self, host, port, project, engine, region_name, secrets_store, hostname_verification, trust_store_path, cert_folder, api_key_file, api_key_value)
# E                       138         self._rules_api = rules_api.RulesApi()
# E                       139
# E                   --> 140         self.connect()
# E                       141
# E                       142     @connected
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/decorators.py in if_not_connected(inst, *args, **kwargs)
# E                        23         if inst._connected:
# E                        24             raise HopsworksConnectionError
# E                   ---> 25         return fn(inst, *args, **kwargs)
# E                        26
# E                        27     return if_not_connected
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/connection.py in connect(self)
# E                       197             # init client
# E                       198             if client.base.Client.REST_ENDPOINT not in os.environ:
# E                   --> 199                 client.init(
# E                       200                     "external",
# E                       201                     self._host,
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/client/__init__.py in init(client_type, host, port, project, engine, region_name, secrets_store, hostname_verification, trust_store_path, cert_folder, api_key_file, api_key_value)
# E                        39             _client = hopsworks.Client()
# E                        40         elif client_type == "external":
# E                   ---> 41             _client = external.Client(
# E                        42                 host,
# E                        43                 port,
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/client/external.py in __init__(self, host, port, project, engine, region_name, secrets_store, hostname_verification, trust_store_path, cert_folder, api_key_file, api_key_value)
# E                        72         self._verify = self._get_verify(self._host, trust_store_path)
# E                        73
# E                   ---> 74         project_info = self._get_project_info(self._project_name)
# E                        75         self._project_id = str(project_info["projectId"])
# E                        76
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/client/external.py in _get_project_info(self, project_name)
# E                       248         :rtype: dict
# E                       249         """
# E                   --> 250         return self._send_request("GET", ["project", "getProjectInfo", project_name])
# E                       251
# E                       252     def _get_credentials(self, project_id):
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/decorators.py in if_connected(inst, *args, **kwargs)
# E                        33         if not inst._connected:
# E                        34             raise NoHopsworksConnectionError
# E                   ---> 35         return fn(inst, *args, **kwargs)
# E                        36
# E                        37     return if_connected
# E
# E                   ~/.local/lib/python3.9/site-packages/hsfs/client/base.py in _send_request(self, method, path_params, query_params, headers, data, stream, files)
# E                       154
# E                       155         if response.status_code // 100 != 2:
# E                   --> 156             raise exceptions.RestAPIError(url, response)
# E                       157
# E                       158         if stream:
# E
# E                   RestAPIError: Metadata operation error: (url: https://791bb4a0-bb1c-11ec-8721-7bd8cdac0b54.cloud.hopsworks.ai/hopsworks-api/api/project/getProjectInfo/prod). Server response:
# E                   HTTP code: 401, HTTP reason: Unauthorized, error code: 320002, error msg: Api key not found, user msg:
# E                   RestAPIError: Metadata operation error: (url: https://791bb4a0-bb1c-11ec-8721-7bd8cdac0b54.cloud.hopsworks.ai/hopsworks-api/api/project/getProjectInfo/prod). Server response:
# E                   HTTP code: 401, HTTP reason: Unauthorized, error code: 320002, error msg: Api key not found, user msg:
#
# /usr/lib/python3/dist-packages/nbconvert/preprocessors/execute.py:448: CellExecutionError
#
# During handling of the above exception, another exception occurred:
#
# notebook = 'notebooks/feature_engineering.ipynb'
#
# >   ???
# E   AssertionError: Failed executing notebooks/feature_engineering.ipynb
# E   assert False
#
# /home/jdowling/Projects/ml-testing/ex2/notebook-tests/test_features_notebook.py:13: AssertionError
# =============================== warnings summary ===============================
# ../../../../usr/lib/python3/dist-packages/nbconvert/exporters/html.py:77
#   /usr/lib/python3/dist-packages/nbconvert/exporters/html.py:77: DeprecationWarning: 'contextfilter' is renamed to 'pass_context', the old name will be removed in Jinja 3.1.
#     def markdown2html(self, context, source):
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED notebook-tests/test_features_notebook.py::test_notebook_exec[notebooks/feature_engineering.ipynb]
# 1 failed, 1 warning in 3.49s
